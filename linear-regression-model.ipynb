# %%
import pandas as pd

df = pd.read_csv('./data/train_truncated.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8348650 entries, 0 to 8348649
# Data columns (total 7 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   pickup_hour_bin   float64
#  1   pickup_day_bin    float64
#  2   pickup_month_bin  float64
#  3   pickup_year_bin   float64
#  4   passenger_count   float64
#  5   distance_km       float64
#  6   fare_amount       float64
# dtypes: float64(7)
# memory usage: 445.9 MB

# %%
df.head()
# Out:
#    pickup_hour_bin  pickup_day_bin  pickup_month_bin  pickup_year_bin  \
# 0         0.535057       -0.082026         -0.077711        -1.466758
# 1        -2.107859        0.263273          0.503347        -0.396560
# 2        -1.485997        0.608571         -0.658768         0.138540
# 3        -1.019600       -0.772622         -0.949297        -0.931659
# 4         1.001454        0.493472          1.374933         0.138540
#
#    passenger_count  distance_km  fare_amount
# 0        -0.526745    -0.529601          4.5
# 1         0.239076    -0.440319          5.7
# 2        -0.526745    -0.193465          7.7
# 3        -0.526745    -0.317751          5.3
# 4        -0.526745    -0.421270          7.5

# %%
df.T.to_csv('./data/train_truncated_transposed.csv', index=False)

# %%
from sklearn.linear_model import SGDRegressor
# Train a linear regression model
model = SGDRegressor(penalty=None, max_iter=1000, tol=1e-3)

# %%
model.fit(df.drop(columns=['fare_amount']), df['fare_amount'])
# Out:
# SGDRegressor(penalty=None)

# %%
model.coef_
# Out:
# array([0.07688799, 0.02021641, 0.31984105, 1.01396323, 0.06460809,
#        6.9159808 ])

# %%
# Get MSE on the training set
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['fare_amount'], model.predict(df.drop(columns=['fare_amount'])))
print(f'Mean Squared Error on training set: {mse}')
# Out:
# Mean Squared Error on training set: 41.97722752441809

# %%
predictions = [-0.031273,0.030548,0.236698,0.032003,-0.144148,-0.010978,-0.338925,-0.009031,-0.340739,0.294702,0.054050,-0.201771,-0.420079,-0.288017,0.137958,-0.288191,-0.378204,0.110604,0.241164,-0.136272,-0.075714,0.268051,0.033124,-0.273219,-0.349944,0.154995,0.137455,0.315578,0.014494,-0.166950,0.380737,-0.075532,-0.167203,-0.089755,0.170291,-0.283813,-0.248982,0.116161,0.498008,-0.416663,-0.336945,0.404534,-0.211006,-0.274520,-0.015244,0.246259,0.196473,0.265616,0.067294,-0.125441,0.328932,0.383982,0.114526,-0.011368,-0.288945,0.047620,0.165749,-0.398387,-0.030623,-0.478314,-0.005105,-0.083920,-0.036339,0.021326,0.271350,-0.388689,0.200043,0.167754,-0.024486,0.306431,-0.104699,0.081426,0.116654,-0.220434,-0.299270,-0.377933,0.122060,-0.038196,-0.178911,-0.391491,0.015530,-0.264775,0.330620,-0.121295,-0.360376,0.177185,-0.047143,-0.463067,-0.439661,0.071503,0.378998,0.024062,-0.072719,0.018159,-0.346909,-0.088171,0.006160,-0.080023,-0.042882,-0.069787,0.043211,0.161482,-0.303638,-0.220904,-0.170666,-0.051100,0.141571,-0.126538,-0.449050,0.423687,0.160953,0.387092,0.171784,0.053907,0.189344,-0.116177,0.074014,-0.138217,0.156858,0.048601,0.198873,0.355440,-0.083294,0.053245,-0.211912,0.135097,0.312028,-0.385281]
[-1.952394,-0.427324,-1.239826,0.138540,2.536536,1.956548],
[-1.175065,0.608571,1.665462,0.138540,-0.526745,0.031269],
[0.379592,-1.693418,1.374933,1.208738,0.239076,-0.467601],
[0.690523,1.184068,-1.530354,0.673639,-0.526745,-0.564628],
[-0.397737,0.493472,-0.368239,0.673639,-0.526745,-0.361754],
[-1.019600,1.759565,-0.368239,1.743838,1.004896,0.622290],
[-0.553202,1.068969,-0.077711,-1.466758,-0.526745,-0.215663],
[0.535057,0.838770,0.212818,-1.466758,-0.526745,0.091059],
[0.224126,0.378372,-0.949297,-0.396560,-0.526745,-0.181045],
[-0.397737,-1.117921,-0.368239,-0.396560,-0.526745,-0.350257],
[-0.708668,-0.887722,-1.239826,0.673639,-0.526745,-0.215018],
[1.312386,-0.312225,-0.368239,1.208738,-0.526745,4.113876],
[1.312386,0.378372,-0.658768,1.743838,-0.526745,-0.242368],
[-1.019600,0.148173,-0.368239,-0.931659,-0.526745,1.131719],
[-0.708668,0.263273,-0.658768,1.743838,-0.526745,-0.510065],
[-0.086805,1.299168,-1.239826,-1.466758,0.239076,0.594155],
[1.001454,0.033074,0.212818,-1.466758,0.239076,0.263563],
[-0.086805,0.033074,-0.368239,-0.396560,-0.526745,-0.122956],
[1.156920,-0.772622,0.503347,0.673639,-0.526745,-0.389533],
[0.224126,-0.197125,-0.949297,-0.931659,2.536536,-0.536713],
[-0.086805,1.299168,-0.658768,-0.396560,-0.526745,-0.535417],
[-0.242271,-1.348119,1.374933,1.208738,-0.526745,-0.516870]
]

# %%
import numpy as np

# calculate gradients from predictions, true weight and for each data point and aggregate to each feature
gradients = []
for i in range(len(predictions)):
    grad = (predictions[i] - true_labels[i]) * np.array(data_points[i])
    gradients.append(grad)

gradients = pd.DataFrame(gradients)
# calculate the mean gradient for each feature
mean_gradients = gradients.mean()
print("Mean gradients for each feature:")
print(mean_gradients)
# Out:
# Mean gradients for each feature:
# 0    0.964176
# 1    2.290129
# 2    0.684469
# 3   -1.543490
# 4   -1.041032
# 5   -5.212731
# dtype: float64

# %%
gradients.loc[0]
# Out:
# 0   -2.424489
# 1    0.371682
# 2    0.352130
# 3    6.646281
# 4    2.386825
# 5    2.399767
# Name: 0, dtype: float64

# %%
# Calculate MSE for the predictions
mse_predictions = mean_squared_error(true_labels, predictions)
print(f'Mean Squared Error for predictions: {mse_predictions}')
# Out:
# Mean Squared Error for predictions: 201.97202205491584

# %%
weights = np.array([-0.025909,0.160159,-0.149896,0.017477,0.011926,-0.030202])
# update weights using the mean gradients
updated_weights = weights - 0.001 * mean_gradients.values
print("Updated weights after applying mean gradients:")
print(updated_weights)
# Out:
# Updated weights after applying mean gradients:
# [-0.02687318  0.15786887 -0.15058047  0.01902049  0.01296703 -0.02498927]

# %%
-0.025909 0.160159 -0.149896 0.017477 0.011926 -0.030202

-0.026873 0.157869 -0.150581 0.019020 0.012967 -0.024990

# %%
